# %% [markdown]
# # Chapter 7 Exercises
# ## Exercise 7.1
#
# After fine-tuning the model with the Alpaca prompt style, try the Phi-3 prompt style and observe whether it affects the response quality of the model.

# %% [markdown]
# ## Exercise 7.2
#
# After completing the chapter and fine-tuning the model with `InstructionDataset`, replace the instruction and input tokens with the -100 mask to use the instruction masking method where the instruction tokens do not affect the loss computation. Then evaluate whether this has a positive effect on model performance.

# %% [markdown]
# ## Exercise 7.3
#
# The Alpaca dataset, by researchers at Stanford, is one of the earliest and most popular openly shared instruction datasets, consisting of 52,002 entries. As an alternative to the instruction-data.json file we use here, consider fine-tuning an LLM on this dataset. The dataset is available at https://mng.bz/NBnE.

# %% [markdown]
# ## Exercise 7.4
#
# To instruction fine-tune an LLM more efficiently, modify the code in this chapter to use the low-rank adaptation method (LoRA) from appendix E. Compare the training run time and model performance before and after the modification.
